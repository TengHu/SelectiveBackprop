# %%
import pickle
import matplotlib.pyplot as plt
import numpy as np

# %%
with open("./logger.blob.pickle", 'rb') as handle:
    run = pickle.load(handle)

# %%
run.keys()
# Out:
# dict_keys(['test_acc', 'num_bps', 'num_fps', 'total_bps', 'total_fps'])

# %%
len(np.array(run['num_fps']) / run['total_fps'])
# Out:
# 3519

# %%
plt.plot(run['total_fps'])

# %%
plt.plot(run['num_bps'])

# %%
plt.plot(np.array(run['total_bps']))
