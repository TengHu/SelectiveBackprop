# %%
import pickle
import matplotlib.pyplot as plt
import numpy as np

# %%
with open("./logger.blob.pickle", 'rb') as handle:
    run = pickle.load(handle)

# %%
run.keys()
# Out:
# dict_keys(['global_num_skipped_fp', 'global_num_skipped', 'test_epoch_acc', 'test_acc', 'global_num_forwards', 'test_loss', 'global_num_backpropped'])

# %%
plt.plot(run['global_num_backpropped'])

# %%
plt.plot(np.array(run['global_num_backpropped'])[1:] / 1000000, 1 - np.array(run['test_epoch_acc'])[1:])
